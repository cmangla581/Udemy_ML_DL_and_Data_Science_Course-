# %% [markdown]
#                                               Working with the File Paths

# %%
import os 

cwd  =os.getcwd() 
print(f"Current working directory is: {cwd}")
# Out:
# Current working directory is: d:\Coding\Udemy Course ML,DL,NLP\Module8 Python File Handling

# %% [markdown]
# Hence, in the above code we can see that, we get the location of the current working directory

# %% [markdown]
# Now, we will see the creation of a new directory package as:

# %%
new_directory  = "package" 
os.mkdir(new_directory) 

print(f"Directory  '{new_directory}' created")
# Out:
# Directory  'package' created

# %% [markdown]
# In the above code we can see that the new directory named as package is created and hence the code is implemented.

# %%
# Listing the files and directories present in the folder 

items = os.listdir('.') 
print(items)
# Out:
# ['destination.txt', 'example.bin', 'example.txt', 'examples.txt', 'File_Operation_Python.ipynb', 'package', 'source.txt', 'Working_with_File_Paths.ipynb']

# %% [markdown]
# In the above code, as we can see that the items present in the file get printed and hence this shows the whole list of the directory.

# %% [markdown]
# Joining Paths
#
# The Joining Paths is basically used to  cnnstruct the file and directory paths in a robust and cross platform way, avoiding the manual string concatenation errors.
#
# The functionality is achieved using the methods like the os.path.joint() from the os module or the operator with pathlib.path objects.

# %%
dir_name = "folder" 

file_name = "file.txt" 

full_path = os.path.join(dir_name, file_name) 

print(full_path)  

# Here as we can see in the output thaat we have got the full path location of the file
# Out:
# folder\file.txt

# %%
# Now, suppose if we want the full path of the file, then the code would be: 
dir_name = "folder"

file_name = 'file.txt' 

full_path = os.path.join(os.getcwd(),dir_name, file_name)  

print(full_path) 

# Here, as we can see that we get the full path
# Out:
# d:\Coding\Udemy Course ML,DL,NLP\Module8 Python File Handling\folder\file.txt

# %%
path = 'example1.txt'  
if os.path.exists(path): 
    print(f"The path '{path}' exists")  

else: 
    print(f"The path '{path}' does not exist")  

# Here it tells that the file example1 does not exist
# Out:
# The path 'example1.txt' does not exist

# %%
# checking if the path is a file or directory 

path = 'example.txt' 

if os.path.isfile(path): 
    print(f"The path '{path}' is a file") 

elif os.path.isdir(path): 
    print(f"The path '{path}' is a directory") 

else: 
    print(f"The path '{path}' is neither a file nor a directory")
# Out:
# The path 'example.txt' is a file

# %%
# Getting the absolute path 

relative_path = 'example.txt'  

absolute_path = os.path.abspath(relative_path) 

print(absolute_path)  

# here we get the absolute path
# Out:
# d:\Coding\Udemy Course ML,DL,NLP\Module8 Python File Handling\example.txt
