# %% [markdown]
#                                                   Module 1 Exercise Questions

# %% [markdown]
# Q1. Write a Python program to print \"Hello, World! .

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# Q2.  Write a Python program that takes a user input and prints it.

# %%
a = int(input("Enter the number: ")) 
print(a) 

# 23 number is printed on input
# Out:
# 23

# %% [markdown]
# Q3.  Write a Python program to check if a number is positive, negative, or zero.

# %%
n = int(input("Enter teh number: ")) 

if n > 0: 
    print("Positive Number") 

elif n < 0: 
    print("Negative Number") 

else: 
    print("Number is Zero") 

# 56
# Out:
# Positive Number

# %%
n = int(input("Enter teh number: ")) 

if n > 0: 
    print("Positive Number") 

elif n < 0: 
    print("Negative Number") 

else: 
    print("Number is Zero") 

# -48
# Out:
# Negative Number

# %% [markdown]
# Q4. Write a Python program to find the largest of three numbers.

# %%
# Find the largest of three numbers  

a= int(input("Enter the first number"))
b= int(input("Enter the second number"))
c= int(input("Enter the third number")) 

if a>b and a>c : 
    print("a is the largest") 

elif b>a and b>c : 
    print("b is the largest") 

else: 
    print("c is the largest")  

# 3,4,5 was the input
# Out:
# c is the largest

# %% [markdown]
# Q5.  Write a Python program to calculate the factorial of a number.

# %%
n = int(input("enter a number: ")) 

factorial = 1 

if n < 0: 
    print("Factorial is not possible for negative numbers") 

else: 
    for i in range(1, n+1): 
        factorial = factorial*i 
    
    print(f"Factorial of {n} is {factorial}")
# Out:
# Factorial of 5 is 120

# %% [markdown]
# Q6. Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
# The code for creating the variables 

a = 5 
print(a) 
print(type(a)) 

b = 6.7 
print(b) 
print(type(b)) 

c =  "Chaitanya Mangla" 
print(c) 
print(type(c)) 

d = True
print(d) 
print(type(d))
# Out:
# 5
# <class 'int'>
# 6.7
# <class 'float'>
# Chaitanya Mangla
# <class 'str'>
# True
# <class 'bool'>

# %% [markdown]
# Q7. Write a Python program to swap the values of two variables.

# %%
# Without using a third Variable 

a= int(input("Enter the first number: ")) 
b = int(input("enter the second number: ")) 

a,b = b,a 

print("After Swapping") 
print("a:", a) 
print("b:", b) 

# a = 45, b = 67
# Out:
# After Swapping
# a: 67
# b: 45

# %%
# Using a third variable 
a = int(input("Enter the second number: ")) 
b = int(input("Enter the Second Number: ")) 

temp = a 
a = b 
b = temp  

print("After Swapping") 
print("a:", a) 
print("b", b)  

# a = 23, b = 34
# Out:
# After Swapping
# a: 34
# b 23

# %% [markdown]
# Q8.  Write a Python program to convert Celsius to Fahrenheit.

# %%
celsius = float(input("Enter temperature in Celsius: ")) 

fahrenheit = (celsius * 9/5) + 32 

print("Temperature in Fahrenheit: ", fahrenheit)  

# 5 in input
# Out:
# Temperature in Fahrenheit:  41.0

# %% [markdown]
# Q9.  Write a Python program to concatenate two strings.

# %%
a = input("Enter the first string: ") 
b=  input("Enter teh second string: ") 

result = a + b 

print(result)
# Out:
# ChaitanyaMangla

# %% [markdown]
# Q10. Write a Python program to check if a variable is of a specific data type.

# %%
x = 345 

if type(x) == int: 
    print("x is of the type int") 

else: 
    print("x is not of the type int")
# Out:
# x is of the type int

# %% [markdown]
# Q11. Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
a = int(input("enter the first number: "))
b = int(input("Enter the second number: ")) 

add = a+b 
sub = a-b 
mul = a*b 
div = a/b 

print(add)
print(sub)
print(mul)
print(div)  

# 25 and 5
# Out:
# 30
# 20
# 125
# 5.0

# %% [markdown]
# Q12. Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
a = 10 
b = 5 

print("a:",a)
print("b:", b) 

# Equal to 
print("a == b", a==b) 

# Not equal to 
print("a != b", a!=b) 

# Greater than 
print("a > b" , a>b) 

# Less than 
print("a<b", a<b)
# Out:
# a: 10
# b: 5
# a == b False
# a != b True
# a > b True
# a<b False

# %% [markdown]
# Q13. Write a Python program to demonstrate logical operators: and, or, not.

# %%
a = 10 
b = 5 

print("a:",a) 
print("b:",b) 

# Logical AND 
print("(a > 5 and b > 2):", a>5 and b>2) 

# Logical OR 
print("(a>5 or b>2): ", a>15 or b>2) 

# Logical NOT 
print("not(a > 5):", not (a>5))
# Out:
# a: 10
# b: 5
# (a > 5 and b > 2): True
# (a>5 or b>2):  True
# not(a > 5): False

# %% [markdown]
# Q14.  Write a Python program to calculate the square of a number.

# %%
a = int(input("Enter the number: ")) 

result = a**2 

print(result) 

# input = 23
# Out:
# 529

# %% [markdown]
# Q15.   Write a Python program to check if a number is even or odd.

# %%
n = int(input("enter the number: ")) 

if n%2 == 0: 
    print("Even Number") 

else: 
    print("Odd Number") 

# Numberinput = 45
# Out:
# Odd Number

# %% [markdown]
# Q16.  Write a Python program to find the sum of the first n natural numbers.

# %%
# To find the sum of the numbers  

n = int(input("Enter a number: ")) 

sum = 0 
for i in range(1, n+1): 
    sum += i 

print(f"Sum of first{n} natural numbers is: {sum}")
# Out:
# Sum of first5 natural numbers is: 15

# %% [markdown]
# Q17. Write a Python program to check if a year is a leap year.

# %%
year = int(input("Enter a year: ")) 

if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
    print(f"{year} is a leap year") 

else: 
    print(f"{year} is not a leap year")
# Out:
# 1900 is not a leap year

# %% [markdown]
# Q18.  Write a Python program to reverse a string.

# %%
text = input("enter a string: ") 

reversed_text = text[::-1]  

print("Reversed String: ", reversed_text)  

# Input = Chaitanya Mangla
# Out:
# Reversed String:  algnaM aynatiahC

# %% [markdown]
# Q19.  Write a Python program to check if a string is a palindrome.

# %%
# Method 1 

def palindrome(n): 
    return str(n) == "".join(reversed(str(n))) 

n = int(input("Enter a number: ")) 

if palindrome(n) : print("The number is a palindrome") 

else: print("The number is not a palindrome") 

# 121
# Out:
# The number is a palindrome

# %%
text = input("Enter a string: ") 

if text == text[::-1]:
    print("The string is a palindrome") 
else: 
    print("The string is not a palindrome") 

# 345
# Out:
# The string is not a palindrome

# %% [markdown]
# Q20.  Write a Python program to sort a list of numbers in ascending order.

# %%
numbers = [5,2,9,1,3] 

numbers.sort()  

print("Sorted List: ", numbers)
# Out:
# Sorted List:  [1, 2, 3, 5, 9]
