# %% [markdown]
#                                                     Python Variables
#                             Here, we are going to talk about the Python Variables and see the code examples.

# %% [markdown]
# Variables are the fundamental elements in programming used to store the data and used to store the data that can be referenced and also manipulated in a program.
#
# In Python, the variables are created when you assign a value to them and also they do not explicit declaration to reserve memory space and the declaration happens automatically.

# %%
a = 100 
# Here a = 100 means that the variable a is assigned a value 100.

# %%
# Example of declaring and assigning the variables  

age = 32 
height = 6.1 
name = "Krish" 
is_student = True 

# printing the variables 
print("age :", age) 
print("Height: ", height) 
print("Name: ", name)
# Out:
# age : 32
# Height:  6.1
# Name:  Krish

# %% [markdown]
# Naming conventions:
# 1. variable names should be descriptive.
# 2. They must always start with a letter or _ and theymust contain the letters, numbers and underscores.
# 3. Variables names are case sensitive.
#
# Python is a dynamic type of programming language as a variable is determined at runtime.

# %%
# Valid Variable names  
first_name = "Chaitanya" 
last_name = "Naik" 

# This a good way of writing our variables.

# %%
# Invalid variable names 
first-name = 'Krish' 
@name = "Krish"
# Out:
#   Cell In[4], line 2
#     first-name = 'Krish'
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
type(height) 
# The data type of height variable is float
# Out:
# float

# %%
age = 25 
print(type(25)) 

age_str = str(age) 
print(age_str) 
print(type(age_str))
# Out:
# <class 'int'>
# 25
# <class 'str'>

# %%
name = "Krish" 
int(name) 

# Here we cannot convert hte integer just like that into the string.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 2
#       1 name = "Krish"
# ----> 2 int(name)
#
# ValueError: invalid literal for int() with base 10: 'Krish'

# %%
height = 5.11 
type(height) 

# Here as we cna see that the height is of the float type
# Out:
# float

# %%
float(int(height)) 
# conversion to float
# Out:
# 5.0

# %% [markdown]
# Dynamic Typing means that the program allows the typpe of variable to change as the the program executes.

# %%
var = 10 
print(var, type(var))
# Out:
# 10 <class 'int'>

# %%
var = "hello" 
print(var,type(var))
# Out:
# hello <class 'str'>

# %%
# Simple calculator 

num1 = float(input("enter the first number "))
num2 = float(input("enter the second number ")) 

sum = num1 + num2 
difference = num1 - num2 
product  = num1 * num2 
quotient = num1 / num2 

print("Sum: ", sum) 
print("Difference: ", difference)
print("Product: ", product)
print("Quotient: ", quotient) 

# 56 and 8
# Out:
# Sum:  64.0
# Difference:  48.0
# Product:  448.0
# Quotient:  7.0
