# %% [markdown]
#                                                            Basics of Python
# here we will be covering about the basics of Python and will be talking about its syntax and Semantics.

# %% [markdown]
# Syntax refers to the set of rules that defines the combinations of symbols that are considered to be correctly structured programs in a language and also syntax is about the correct arrangemnt of the words and symbols in the code.

# %% [markdown]
# Semantics refers to the meaning of the interpretation of the symbols, characters and commands in a language and also it is about, what the code is supposed to do when it runs.

# %% [markdown]
# For single line comments, we use hashtag and for the multipline comments we use apostrophe commas.

# %%
# Python is a case sensitive language and the same words cannot be used for at 2 differnt places.  

'''
Python is a programming language that has vast uses and cna be used in the fields of Data Science, Machine Learning, Deep Learning, NLP, 
Game developmenr, web development and many more. 
 '''

# %% [markdown]
# Python is a case sensitive langusge. its example is shown below as:

# %%
name = "chaitanya" 
Name = "Mangla" 

print(name) 
print(Name)
# Out:
# chaitanya
# Mangla

# %% [markdown]
# Here, as we can see that in the above code, we can see that the 2 variables are being treated as the 2 different variables or 2 different names and hence different names are being written here.

# %% [markdown]
# Indentation in Python is used to define the structure and the hierarchy of the code. Unlike many othe rprogramming languages, that uses the {} to delimit the block of code. This means that the block of the code must be intended at the same time of the code.
#
# Python uses indentation to define the blocks of code and hence the use of consistent use of the spaces or a tab is required.

# %%
# Example of indentation  

age = 32 
if age>30:
    print(age) 

print(age)
# Out:
# 32
# 32

# %% [markdown]
# In the above code as we can see that the age gets printed for 2 times due to the theory of indentation.

# %%
print("Hello World")
# Out:
# Hello World

# %%
# Now we will see the line continuation 
total = 1+2+3+4+5+6+7+\
4+5+6 

print(total)  

# Here as we can see tha the total is  done here
# Out:
# 43

# %%
# Multiple Statements on a single line 
x=5; y=10; z= x+y
print(z)  

# Here as we can see that the comments are made
# Out:
# 15

# %%
# Understand the Semantics in Python 

# Variable Assignment 
age = 32 
# Here as we can see that age is a variable assignment and is an integer 

name = "chaitanya" 
# Here as we can see that the name is a string

# %%
# Type Inference  
variable = 10 
print(type(variable))  

# Here in the output, we can see that the type of  variable gets printed in the output and its showing integer
# Out:
# <class 'int'>

# %%
variable = "Chaintanya" 
print(type(variable)) 

# Here as we can see that the type of the variable gets printed as string
# Out:
# <class 'str'>

# %%
# Code examples on indentation 
if True: 
    print("Correct Indentation") 
    if False: 
        print("This won't print") 
    print("this will print") 
print("Outside the if block")
# Out:
# Correct Indentation
# this will print
# Outside the if block
