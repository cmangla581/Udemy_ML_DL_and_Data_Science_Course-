# %% [markdown]
#                                                   Lambda Functions

# %% [markdown]
# Lambda Functions are those which are small annonymous functions defined using the lambda function. They can hve a number of arguments but only one expression. They are commonly used for theshort operationsor as arguments to higher ordr functions.

# %% [markdown]
# Syntax
#
# lambda Arguments Expression

# %%
def addition(a,b): 
    return a+b 

addition(4,5)
# Out:
# 9

# %%
additin = lambda a,b: a+b 
print(type(addition)) 

print(addition(5,6)) 

# The function is there and also the addition of the numbers is printed
# Out:
# <class 'function'>
# 11

# %%
# Example of even function 
def even_function(n): 
    if n%2 == 0: 
        return True 

even_function(24)
# Out:
# True

# %%
even1 = lambda num:num%2 == 0
even1(12) 

# Here as in the above code we can see that th code can  

def addition(x,y,z): 
    return x+y+z 

addition(3,4,5)
# Out:
# 12

# %%
addition1 = lambda x, y,z : x+y+z 

addition1(12,13,14) 

# The addition takes place
# Out:
# 39

# %%
# MAp Function  applies to all items in a list of thefunction 
numbers = [1,2,3,4,5,6]  

def square(number): 
    return number**2 

square(2) 

# The square of thenumber gets printed
# Out:
# 4

# %%
# Mapping function 

list(map(lambda x:x**2, numbers))
# Out:
# [1, 4, 9, 16, 25, 36]

# %% [markdown]
# In the above code, we can see that due to the mapping function, the function gets applied to all the values of the elements of the list
