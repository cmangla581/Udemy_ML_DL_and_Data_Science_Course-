# %% [markdown]
#                                                  Function Coding Questions

# %% [markdown]
# Q1. Temperature Conversion

# %%
#  conversion of the temperature 

def convert_temperature(temp, unit):
    """The function converts the temperature between the Celsius and Fahrenheit""" 

    if unit == 'C': 
        return temp * 9/5 + 32  # Celsius to Fahrenheit 

    elif unit == 'F': 
        return (temp - 32) * 5/9 

    else: 
        return None 

print(convert_temperature(25, 'C')) 
print(convert_temperature(77, 'F'))   

# reer as we can see that the conversion from Celsius and Fahrenheit and reverse takes place
# Out:
# 77.0
# 25.0

# %% [markdown]
# Q2. Strong Password Checker

# %%
# The  StrongPassword Checker  
def is_strong_password(password): 
    """This function checks if the password is strong or not""" 
    if len(password) < 8: 
        return False 
    if not any(char.isdigit() for char in password): 
        return False 
    if not any(char.islower() for char in password): 
        return False
    if not any(char.isupper() for char in password): 
        return False 
    if not (char in '!#@$%^&*()_+' for char in password):
        return False
    return True  

# calling the Function 
print(is_strong_password("WeakPad"))
print(is_strong_password("Str0ngPwd!")) 

# Here as we can see that whether the ppassword is True or False is there
# Out:
# False
# True

# %% [markdown]
# Q3. Calculate the total cost of items in  ashopping cart.

# %%
def calculate_total_cost(cart): 
    total_cost = 0
    for item in cart: 
        total_cost += item['price'] * item['quantity'] 

    return total_cost 

cart = [
    {'name': 'Apple', 'price':0.5, 'quantity':4}, 
    {'name':'Banana', 'price':0.3, 'quantity':6}, 
    {'naem':'orange', 'price':0.7,'quantity':3} 
]

total_cost = calculate_total_cost(cart) 
print(total_cost) 

# Here, as we can see that the total cost has been printed
# Out:
# 5.8999999999999995

# %% [markdown]
# Q4. Check if a string is a palindrome  or not

# %%
def is_palindrome(text):
    if text == text[::-1]:
        print(f"{text} is a palindrome") 
    else:
        print(f"{text} is not a palindrome")

is_palindrome("121") 
is_palindrome("345")
# Out:
# 121 is a palindrome
# 345 is not a palindrome

# %% [markdown]
# Q5. Calculate the factorial of a number using the function recursion.

# %%
# The code for printing the actorial of a number using the function recursion 
def factorial(n): 
    if n==0:
        return 1 
    else: 
        return n*factorial(n-1) 
    
n = int(input('Enter the number: ')) 

print(f"The factorial of {n} is {factorial(n)}") 

# Here the factorial is  getting printed
# Out:
# The factorial of 5 is 120

# %% [markdown]
# Q6. A Function to read a file and count the frequncy of each word

# %%
# The code for the above code as: 

def  count_word_frequency(file_path): 
    word_count = {} 

    with open(file_path, 'r') as file: 
        for line in file: 
            words = line.split() 
            for word in words: 
                word = word.lower().strip('.,!?;:"\'') 
                word_count[word] = word_count.get(word,0)+1  
    return word_count 

filepath = 'sample.txt'  
word_frequency = count_word_frequency(filepath) 
print(word_frequency)
# Out:
# {'hell': 1, 'world': 2, 'my': 1, 'name': 1, 'in': 1, 'is': 1, 'chaitanya': 1, 'mangla': 1}

# %% [markdown]
# Q7. Validate Email Address.

# %%
import re  

# Email Validation Function  
def is_valid_email(email): 
    pattern = r'^[a-zA-z0-9_.+-]+@[a-zA-Z0-9]+\.[a-zA-Z0-9-,]+$' 
    return re.match(pattern, email) is not None 

print(is_valid_email("test@example.com")) 
print(is_valid_email("invalid email"))
# Out:
# True
# False
