# %% [markdown]
# # Pandas Assignment

# %% [markdown]
# # Assignment 1

# %% [markdown]
# Q1. Create a Pandas DataFrame with 4 columns and 6 rows filled with random integers. Set the index to be the first column.

# %%
# The code for the above question is as: 
import numpy as np 
import pandas as pd 

df = pd.DataFrame(np.random.randint(1,100, size = (6,4)), columns = ['A', 'B', 'C', 'D']) 
print("Orihginal DataFrame") 
print(df)  

# Set the index to the first column 
df.set_index('A', inplace = True) 
print("Dataframe with new index") 
print(df)
# Out:
# Orihginal DataFrame
#     A   B   C   D
# 0  36  41  19  91
# 1  94  86  76  95
# 2  45  62   5  82
# 3  56  62  91  21
# 4  75  99  98  41
# 5  48  53  34  97
# Dataframe with new index
#      B   C   D
# A
# 36  41  19  91
# 94  86  76  95
# 45  62   5  82
# 56  62  91  21
# 75  99  98  41
# 48  53  34  97

# %% [markdown]
# Q2. Create a Pandas DataFrame with columns 'A', 'B', 'C' and index 'X', 'Y', 'Z'. Fill the DataFrame with random integers and access the element at row 'Y' and column 'B'.

# %%
# The code for the above question is as: 
df = pd.DataFrame(np.random.randint(1,100, size = (3,3)), columns = ['A', 'B', 'C'], index = ['X', 'Y','Z']) 
print("Origibal DataFrame") 
print(df) 

element = df.at['Y', 'B'] 
print("Element at the row Y and column B: ", element)
# Out:
# Origibal DataFrame
#     A   B   C
# X  82  93  37
# Y  60  31  30
# Z  81  28  73
# Element at the row Y and column B:  31

# %% [markdown]
# # Assignment 2

# %% [markdown]
# Q1. Create a Pandas DataFrame with 3 columns and 5 rows filled with random integers. Add a new column that is the product of the first two columns.

# %%
# The code for the question is as: 
df = pd.DataFrame(np.random.randint(1,100, size = (5,3)), columns = ['A', 'B', 'C']) 
print("Original DataFrame") 
print(df) 

# A new column that is  the product of the 2 new columns 
df['D'] = df['A'] * df['B'] 
print("Data frame with new column") 
print(df)
# Out:
# Original DataFrame
#     A   B   C
# 0  79  58  49
# 1  33   7  25
# 2  27  58   6
# 3  46  29   7
# 4  14   1  20
# Data frame with new column
#     A   B   C     D
# 0  79  58  49  4582
# 1  33   7  25   231
# 2  27  58   6  1566
# 3  46  29   7  1334
# 4  14   1  20    14

# %% [markdown]
# Q2. Create a Pandas DataFrame with 3 columns and 4 rows filled with random integers. Compute the row-wise and column-wise sum.

# %%
# The code for the above question is as: 
df = pd.DataFrame(np.random.randint(1,100, size = (4,3)), columns = ['A', 'B', 'C']) 
print("Original Dataframe") 
print(df) 

row_sum = df.sum(axis = 1) 
column_sum = df.sum(axis = 0) 

print("Row wise Sum") 
print(row_sum) 

print("Column wise sum") 
print(column_sum)
# Out:
# Original Dataframe
#     A   B   C
# 0  23  54   9
# 1   6  89  33
# 2  80  55  34
# 3  10  61  53
# Row wise Sum
# 0     86
# 1    128
# 2    169
# 3    124
# dtype: int64
# Column wise sum
# A    119
# B    259
# C    129
# dtype: int64

# %% [markdown]
# # Assignment 3

# %% [markdown]
# Q1. Create a Pandas DataFrame with 3 columns and 5 rows filled with random integers. Introduce some NaN values. Fill the NaN values with the mean of the respective columns.

# %%
# The code for the above question is as: 

df = pd.DataFrame(np.random.randint(1,100, size = (5,3)), columns = ['A', 'B',  'C']) 
print("Original DataFrame") 
print(df) 

df.iloc[0, 1] = np.nan 
df.iloc[2,2] = np.nan 
df.iloc[4,0] = np.nan 
print("Prinitng the datafame with nana values: ")
print(df)  

# Filling the missing  values with the sum of respective columns as: 
df.fillna(df.mean(), inplace = True) 
print("Data Frame with the Nan Values") 
print(df)
# Out:
# Original DataFrame
#     A   B   C
# 0  24  27  33
# 1  53  31   8
# 2  36  27  51
# 3  27   8  77
# 4  99  59  87
# Prinitng the datafame with nana values:
#       A     B     C
# 0  24.0   NaN  33.0
# 1  53.0  31.0   8.0
# 2  36.0  27.0   NaN
# 3  27.0   8.0  77.0
# 4   NaN  59.0  87.0
# Data Frame with the Nan Values
#       A      B      C
# 0  24.0  31.25  33.00
# 1  53.0  31.00   8.00
# 2  36.0  27.00  51.25
# 3  27.0   8.00  77.00
# 4  35.0  59.00  87.00

# %% [markdown]
# Q2. Create a Pandas DataFrame with 4 columns and 6 rows filled with random integers. Introduce some NaN values. Drop the rows with any NaN values.

# %%
#  The code for the question is as: 
df = pd.DataFrame(np.random.randint(1,100, size = (6,4)), columns =['A', 'B', 'C', 'D']) 
print("Original Dataframe") 
print(df) 

df.iloc[1,2] = np.nan
df.iloc[3,0] = np.nan
df.iloc[5,1] = np.nan 
print("Dataframe ith nan values") 
print(df) 

df.dropna(inplace= True) 
print("Dataframe ith Nan values") 
print(df)
# Out:
# Original Dataframe
#     A   B   C   D
# 0  35  43  23  47
# 1  25  86  91  30
# 2   3  77  23  10
# 3  95  41  59  46
# 4  68  25  27  98
# 5  64  39  91  19
# Dataframe ith nan values
#       A     B     C   D
# 0  35.0  43.0  23.0  47
# 1  25.0  86.0   NaN  30
# 2   3.0  77.0  23.0  10
# 3   NaN  41.0  59.0  46
# 4  68.0  25.0  27.0  98
# 5  64.0   NaN  91.0  19
# Dataframe ith Nan values
#       A     B     C   D
# 0  35.0  43.0  23.0  47
# 2   3.0  77.0  23.0  10
# 4  68.0  25.0  27.0  98

# %% [markdown]
# # Assignment 4

# %% [markdown]
# Q1. Create a Pandas DataFrame with 2 columns: 'Category' and 'Value'. Fill the 'Category' column with random categories ('A', 'B', 'C') and the 'Value' column with random integers. Group the DataFrame by 'Category' and compute the sum and mean of 'Value' for each category.

# %%
# The code for the following question is as: 
df = pd.DataFrame({'Category' : np.random.choice(['A', 'B', 'C'], size = 10), 'Value': np.random.randint(1, 100, size = 10)}) 
print("Original Dataframe") 
print(df) 

grouped = df.groupby('Category')['Value'].agg(['sum', 'mean']) 
print("Grouped data Frame") 
print(df)
# Out:
# Original Dataframe
#   Category  Value
# 0        A     62
# 1        B     34
# 2        B     46
# 3        B     81
# 4        A     39
# 5        A     54
# 6        A      7
# 7        C     26
# 8        A     44
# 9        B     53
# Grouped data Frame
#   Category  Value
# 0        A     62
# 1        B     34
# 2        B     46
# 3        B     81
# 4        A     39
# 5        A     54
# 6        A      7
# 7        C     26
# 8        A     44
# 9        B     53

# %% [markdown]
# Q2. Create a Pandas DataFrame with 3 columns: 'Product', 'Category', and 'Sales'. Fill the DataFrame with random data. Group the DataFrame by 'Category' and compute the total sales for each category.

# %%
# The code for the question is as: 
df = pd.DataFrame({'Product': np.random.choice(['Prod1','Prod2', 'Prod3'], size = 10), 'Category': np.random.choice(['A', 'B', 'C'], size = 10), 'Sales': np.random.randint(1, 100, size=10)})
print("original Dataframe") 
print(df) 

grouped = df.groupby('Category')['Sales'].sum() 
print("Grouped Dataframe") 
print(grouped)
# Out:
# original Dataframe
#   Product Category  Sales
# 0   Prod3        B     18
# 1   Prod1        B     61
# 2   Prod3        A     52
# 3   Prod2        C     26
# 4   Prod1        A      1
# 5   Prod1        B     95
# 6   Prod3        B     44
# 7   Prod3        B     61
# 8   Prod3        C      3
# 9   Prod2        C     56
# Grouped Dataframe
# Category
# A     53
# B    279
# C     85
# Name: Sales, dtype: int32

# %% [markdown]
# # Assignment 5

# %% [markdown]
# Q1. Create two Pandas DataFrames with a common column. Merge the DataFrames using the common column.

# %%
# The code for the question is as: 
df1 = pd.DataFrame({"Key": ['A', 'B', 'C', 'D'], "Value1": np.random.randint(1, 100, size = 4)}) 
df2 = pd.DataFrame({'Key': ['A', 'B', 'C', 'E'], "Value2": np.random.randint(1, 100, size =4)}) 

print(df1) 
print(df2) 

merged = pd.merge(df1, df2, on = 'Key') 
print("Merged DataFrame") 
print(merged)
# Out:
#   Key  Value1
# 0   A      46
# 1   B       6
# 2   C      94
# 3   D      48
#   Key  Value2
# 0   A       5
# 1   B      28
# 2   C      40
# 3   E       4
# Merged DataFrame
#   Key  Value1  Value2
# 0   A      46       5
# 1   B       6      28
# 2   C      94      40

# %% [markdown]
# Q2. Create two Pandas DataFrames with different columns. Concatenate the DataFrames along the rows and along the columns.

# %%
# The code for the  question is as: 
df1 = pd.DataFrame({'A': np.random.randint(1, 100, size = 3), 'B': np.random.randint(1,100, size = 3)}) 
df2 = pd.DataFrame({'C': np.random.randint(1, 100, size =3), 'D': np.random.randint(1, 100, size = 3)}) 

print(df1) 
print(df2) 

concat_rows = pd.concat([df1, df2], axis = 0) 
print("Concatenated Datafrmae(rows):") 
print(concat_rows)  

concat_columns = pd.concat([df1, df2], axis = 1) 
print("Concatenated Columns:")
print(concat_columns)
# Out:
#     A   B
# 0  18  83
# 1  47  68
# 2  72  27
#     C   D
# 0  84  42
# 1  81  62
# 2  27  37
# Concatenated Datafrmae(rows):
#       A     B     C     D
# 0  18.0  83.0   NaN   NaN
# 1  47.0  68.0   NaN   NaN
# 2  72.0  27.0   NaN   NaN
# 0   NaN   NaN  84.0  42.0
# 1   NaN   NaN  81.0  62.0
# 2   NaN   NaN  27.0  37.0
# Concatenated Columns:
#     A   B   C   D
# 0  18  83  84  42
# 1  47  68  81  62
# 2  72  27  27  37

# %% [markdown]
# # Assignment 6

# %% [markdown]
# Q1. Create a Pandas DataFrame with a datetime index and one column filled with random integers. Resample the DataFrame to compute the monthly mean of the values.

# %%
# The code for the question is as: 
date_rng = pd.date_range(start = '2022-01-01', end='2022-12-31', freq='D') 
df = pd.DataFrame(date_rng, columns = ['date']) 
df['data'] = np.random.randint(0, 100, size = len(date_rng)) 
df.set_index('date', inplace = True) 
print(df) 

monthly_mean = df.resample('M').mean() 
print("Monthly mean DataFrame") 
print(monthly_mean)
# Out:
#             data
# date
# 2022-01-01    67
# 2022-01-02     4
# 2022-01-03    79
# 2022-01-04     3
# 2022-01-05    72
# ...          ...
# 2022-12-27    22
# 2022-12-28    41
# 2022-12-29    63
# 2022-12-30    74
# 2022-12-31    37
#
# [365 rows x 1 columns]
# Monthly mean DataFrame
#                  data
# date
# 2022-01-31  50.290323
# 2022-02-28  53.892857
# 2022-03-31  50.225806
# 2022-04-30  45.900000
# 2022-05-31  50.838710
# 2022-06-30  40.866667
# 2022-07-31  52.709677
# 2022-08-31  49.064516
# 2022-09-30  51.633333
# 2022-10-31  52.064516
# 2022-11-30  46.333333
# 2022-12-31  45.129032
# C:\Users\91981\AppData\Local\Temp\ipykernel_11168\1026757785.py:8: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_mean = df.resample('M').mean()

# %% [markdown]
# Q2. Create a Pandas DataFrame with a datetime index ranging from '2021-01-01' to '2021-12-31' and one column filled with random integers. Compute the rolling mean with a window of 7 days.

# %%
# The code for the question is as: 
ate_rng = pd.date_range(start='2021-01-01', end='2021-12-31', freq='D')
df = pd.DataFrame(date_rng, columns=['date'])
df['data'] = np.random.randint(0, 100, size=(len(date_rng)))
df.set_index('date', inplace=True)
print("Original DataFrame:")
print(df)

rolling_mean = df.rolling(window = 7).mean() 
print("Rolling mean Dataframe") 
print(rolling_mean)
# Out:
# Original DataFrame:
#             data
# date
# 2022-01-01    16
# 2022-01-02    85
# 2022-01-03    88
# 2022-01-04    81
# 2022-01-05    48
# ...          ...
# 2022-12-27    11
# 2022-12-28    50
# 2022-12-29    35
# 2022-12-30    37
# 2022-12-31    36
#
# [365 rows x 1 columns]
# Rolling mean Dataframe
#                  data
# date
# 2022-01-01        NaN
# 2022-01-02        NaN
# 2022-01-03        NaN
# 2022-01-04        NaN
# 2022-01-05        NaN
# ...               ...
# 2022-12-27  39.000000
# 2022-12-28  42.714286
# 2022-12-29  37.142857
# 2022-12-30  30.571429
# 2022-12-31  30.714286
#
# [365 rows x 1 columns]

# %% [markdown]
# # Assignment 7

# %% [markdown]
# Q1. Create a Pandas DataFrame with a MultiIndex (hierarchical index). Perform some basic indexing and slicing operations on the MultiIndex DataFrame.

# %%
# The code for the question is as: 
arrays = [['A', 'A', 'B', 'B'], ['one', 'two', 'one', 'two']] 
index = pd.MultiIndex.from_arrays(arrays, names = ('Category', 'Sub Category')) 
df = pd.DataFrame(np.random.randint(1, 100, size = (4,3)), index = index, columns = ['Value1', 'Value2', 'Value3']) 
print("MultiIndex Dataframe") 
print(df) 

print("Indexing as category A") 
print(df.loc['A'])  

print("Slicing at Category B and Sub Category Tw9") 
print(df.loc[('B', 'two')])
# Out:
# MultiIndex Dataframe
#                        Value1  Value2  Value3
# Category Sub Category
# A        one               27      68      90
#          two                8      91      96
# B        one                8       8      64
#          two               13      89      12
# Indexing as category A
#               Value1  Value2  Value3
# Sub Category
# one               27      68      90
# two                8      91      96
# Slicing at Category B and Sub Category Tw9
# Value1    13
# Value2    89
# Value3    12
# Name: (B, two), dtype: int32

# %% [markdown]
# Q2. Create a Pandas DataFrame with MultiIndex consisting of 'Category' and 'SubCategory'. Fill the DataFrame with random data and compute the sum of values for each 'Category' and 'SubCategory'.

# %%
# The code of the question is as: 
arrays = [['A', 'A', 'B', 'B', 'C', 'C'], ['one', 'two', 'one', 'two', 'one', 'two']]
index = pd.MultiIndex.from_arrays(arrays, names=('Category', 'SubCategory'))
df = pd.DataFrame(np.random.randint(1, 100, size=(6, 3)), index=index, columns=['Value1', 'Value2', 'Value3'])
print("MultiIndex DataFrame:")
print(df)

# Compute the sum of values for each 'Category' and 'SubCategory'
sum_values = df.groupby(['Category', 'SubCategory']).sum()
print("Sum of values:")
print(sum_values)
# Out:
# MultiIndex DataFrame:
#                       Value1  Value2  Value3
# Category SubCategory
# A        one              31      38      63
#          two              14      90      17
# B        one              51      27      63
#          two              87      48      99
# C        one              69      54      54
#          two              21      81      27
# Sum of values:
#                       Value1  Value2  Value3
# Category SubCategory
# A        one              31      38      63
#          two              14      90      17
# B        one              51      27      63
#          two              87      48      99
# C        one              69      54      54
#          two              21      81      27

# %% [markdown]
# # Assignment 8

# %% [markdown]
# Q1. Create a Pandas DataFrame with columns 'Date', 'Category', and 'Value'. Create a pivot table to compute the sum of 'Value' for each 'Category' by 'Date'.

# %%
# The code for the queston is as: 
date_rng = pd.date_range(start='2022-01-01', end='2022-01-10', freq='D') 
df = pd.DataFrame({'Date': np.random.choice(date_rng, size = 20), "Category": np.random.choice(['A', 'B', 'C'],size = 20), 'Value': np.random.randint(1, 100, size=20)}) 
print(df)
pivot_table = df.pivot_table(values='Value', index='Date', columns='Category', aggfunc='sum')
print("Pivot Table:")
print(pivot_table)
# Out:
#          Date Category  Value
# 0  2022-01-10        B     86
# 1  2022-01-03        C     63
# 2  2022-01-03        A     24
# 3  2022-01-08        A     59
# 4  2022-01-01        A     50
# 5  2022-01-05        B     29
# 6  2022-01-06        A     49
# 7  2022-01-05        A     56
# 8  2022-01-10        A     79
# 9  2022-01-10        B     38
# 10 2022-01-05        B     14
# 11 2022-01-02        C     96
# 12 2022-01-05        A     35
# 13 2022-01-03        A     11
# 14 2022-01-07        A     10
# 15 2022-01-01        C     34
# 16 2022-01-10        B      4
# 17 2022-01-07        B     72
# 18 2022-01-08        A     12
# 19 2022-01-04        B     95
# Pivot Table:
# Category       A      B     C
# Date
# 2022-01-01  50.0    NaN  34.0
# 2022-01-02   NaN    NaN  96.0
# 2022-01-03  35.0    NaN  63.0
# 2022-01-04   NaN   95.0   NaN
# 2022-01-05  91.0   43.0   NaN
# 2022-01-06  49.0    NaN   NaN
# 2022-01-07  10.0   72.0   NaN
# 2022-01-08  71.0    NaN   NaN
# ...

# %% [markdown]
# Q2. Create a Pandas DataFrame with columns 'Year', 'Quarter', and 'Revenue'. Create a pivot table to compute the mean 'Revenue' for each 'Quarter' by 'Year'.

# %%
# The code for the question is as: 
df = pd.DataFrame({'Year': np.random.choice([2020, 2021, 2022], size=12), 'Quarter': np.random.choice(['Q1', 'Q2', 'Q3', 'Q4'], size=12), 'Revenue': np.random.randint(1, 1000, size=12)})
print("Original Dataframe") 
print(df) 

pivot_table = df.pivot_table(values = 'Revenue', index = 'Year', columns = 'Quarter', aggfunc = 'mean') 
print("Pivot Tables") 
print(pivot_table)
# Out:
# Original Dataframe
#     Year Quarter  Revenue
# 0   2020      Q4      855
# 1   2020      Q4      169
# 2   2022      Q4      839
# 3   2021      Q1      545
# 4   2021      Q4      121
# 5   2022      Q3      779
# 6   2022      Q2       62
# 7   2021      Q3      917
# 8   2020      Q3      640
# 9   2022      Q4      179
# 10  2021      Q3      113
# 11  2020      Q4       61
# Pivot Tables
# Quarter     Q1    Q2     Q3          Q4
# Year
# 2020       NaN   NaN  640.0  361.666667
# 2021     545.0   NaN  515.0  121.000000
# 2022       NaN  62.0  779.0  509.000000

# %% [markdown]
# # Assignment 9

# %% [markdown]
# Q1.  Create a Pandas DataFrame with 3 columns and 5 rows filled with random integers. Apply a function that doubles the values of the DataFrame.

# %%
# The code for te question is as: 
df = pd.DataFrame(np.random.randint(1, 100, size = (5,3)), columns = ['A', 'B','C']) 
print(df) 

df_doubled = df.apply(lambda x: x*2) 
print(df_doubled)
# Out:
#     A   B   C
# 0  20  88  25
# 1  59  65  73
# 2  39  44  66
# 3  62  86  13
# 4  81  15  72
#      A    B    C
# 0   40  176   50
# 1  118  130  146
# 2   78   88  132
# 3  124  172   26
# 4  162   30  144

# %% [markdown]
# Q2. Create a Pandas DataFrame with 3 columns and 6 rows filled with random integers. Apply a lambda function to create a new column that is the sum of the existing columns.

# %%
# The code of the following question is as: 
df = pd.DataFrame(np.random.randint(1,100, size = (0,3)), columns = ['A', 'B', 'C']) 
print(df) 

df['Sum'] = df.apply(lambda row: row.sum(), axis = 1) 
print(df)
# Out:
# Empty DataFrame
# Columns: [A, B, C]
# Index: []
# Empty DataFrame
# Columns: [A, B, C, Sum]
# Index: []

# %% [markdown]
# # Assignment 10

# %% [markdown]
# Q1. Create a Pandas Series with 5 random text strings. Convert all the strings to uppercase.

# %%
# The code for the question is as: 
text_data = pd.Series(['apple', 'banana', 'cherry', 'dates', 'strawbeey']) 
print(text_data) 

uppercase_data = text_data.str.upper()  
print(uppercase_data)
# Out:
# 0        apple
# 1       banana
# 2       cherry
# 3        dates
# 4    strawbeey
# dtype: object
# 0        APPLE
# 1       BANANA
# 2       CHERRY
# 3        DATES
# 4    STRAWBEEY
# dtype: object

# %% [markdown]
# Q2. Create a Pandas Series with 5 random text strings. Extract the first three characters of each string.

# %%
# The code for the question is as: 

text_data = pd.Series(['apple', 'strawberry', 'banana', 'dates', 'elderberry']) 
print(text_data) 

first_three_chars = text_data[:3] 
print("First 3 characters") 
print(first_three_chars)
# Out:
# 0         apple
# 1    strawberry
# 2        banana
# 3         dates
# 4    elderberry
# dtype: object
# First 3 characters
# 0         apple
# 1    strawberry
# 2        banana
# dtype: object
