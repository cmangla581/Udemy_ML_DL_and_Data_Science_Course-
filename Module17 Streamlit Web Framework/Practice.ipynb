# %%
def find_largest(numbers): 
    largest = numbers[0] 

    for num in numbers: 
        if num > largest:
            largest = num 

    return largest

# %%
def find_largest(numbers): 
    largest = numbers[0] 

    for num in numbers: 
        if num > largest: 
            largest = num 

    return largest

# %%
def remove_duplicates(numbers): 
    seen = set() 
    unique_list = [] 

    for num in numbers: 
        if num not in seen: 
            unique_list.append(num) 
            seen.add(num) 
    return unique_list

# %%
def remove_duplicates(numbers): 
    seen = set() 
    unique_list = [] 

    for num in numbers: 
        if num not in seen: 
            unique_list.append(num) 
            seen.add(num) 

    return unique_list

# %%
def find_largest(numbers): 
    largest = numbers[0] 

    for num in numbers: 
        if num > largest: 
            largest   = num 
    return largest

# %%
def find_largest(numbers): 
    largest = numbers[0]

    for num in numbers: 
        if num > largest: 
            largest = num 

    return largest

# %%
def find_largest(numbers): 
    largest = largest[0] 

    for num in numbers: 
        if num > largest: 
            largest = num 

    return largest

# %%
def find_largest(numbers): 
    largest  = numbers[0] 

    for num in numbers: 
        if num > largest:
            largest = num 
    return largest

# %%
def remove_duplicates(numbers):
    seen = set() 
    unique_list = [] 

    for num  in numbers: 
        if num not in seen:
            unique_list.append(num) 
            seen.add(num)
    return unique_list

# %%
def remove_duplicates(numbers): 
    seen = set() 
    unique_list = [] 

    for num in numbers: 
        if num not in seen: 
            unique_list.append(num)
            seen.add(num) 
    return unique_list

# %%
def remove_duplicates(numbers): 
    seen = set() 
    unique_list = [] 

    for num in numbers: 
        if num not in seen: 
            unique_list.append(num) 
            seen.add(num) 
    return unique_list

# %%
def sum(numbers): 
    total = 0 
    for num in numbers: 
        total += sum 
    return total

# %%
def sum(numbers): 
    total = 0 
    for num in numbers: 
        total += sum 
    return total

# %%
# The sum in numbers 
def sum(numbers): 
    total = 0 
    for num in numbers: 
        total += sum 
    return total

# %%
def sum(numbers): 
    total = 0 
    for num in numbers: 
        total += num 
    return total

# %%
def check_unique(nums): 
    return len(nums) == len(set(nums))

# %%
def find_largest(numbers): 
    largest = numbers[0] 

    for num in numbers: 
        if num > largest : 
            largest = num 

    return largest 

nums = [1,2,3,4,5,6,8,9] 

print(find_largest(nums))
# Out:
# 9

# %%
def find_largest(numbers):
    largest = numbers[0] 

    for num in numbers: 
        if num > largest: 
            largest = num 

    return largest 

num = [1,2,3,4,5,6,7,8,9] 
print(find_largest(num))
# Out:
# 9

# %%
# Removing of the duplicate elements 

def remove_duplicates(numbers): 
    seen = set() 
    unique_list = [] 

    for num in numbers: 
        if num not in seen: 
            unique_list.append(num) 
            seen.add(num) 
    return unique_list

# %%
def reverse_list(lst): 
    reversed_list = []
    for i in range(len(lst) -1,-1,-1): 
        reversed_list.append(lst[i]) 
    return reversed_list

# %%
def check_unique(nums): 
    return len(nums) == len(set(nums)) 

lst = [1,2,3,4,5,6]  

print(check_unique(lst))
# Out:
# True

# %%
def remove_duplicates(numbers): 
    seen =  set()  
    unique_list = [] 

    for num  in numbers:
        if num not in seen: 
            unique_list.append(num) 
            seen.add(num) 
        return unique_list  

nums = [1,2,3,4,5,6,7] 
print(remove_duplicates(nums))
# Out:
# [1]

# %%
def remove_duplicates(numbers): 
    seen = set() 
    unique_list = [] 

    for num in numbers: 
        if num not in seen: 
            unique_list.append(num) 
            seen.add(num)  

        return unique_list 
    
nums = [1,2,3,4,5,6,7] 
print(remove_duplicates)

# %%
def check_unique(numbers): 
    return len(num) == len(set(num)) 

lst = [1,2,3,4,5,6,7,8] 
print(check_unique(lst))
# Out:
# True

# %%
def check_unique(numbers): 
    return len(numbers) == len(set(numbers))

# %%
# Checking of the odd and even list 

def check_odd_even(numbers): 
    even_count = 0 
    odd_count = 0 

    for num in numbers: 
        if num%2 == 0: 
            even_count += 1 

        else: 
            odd_count += 1 

    return even_count, odd_count

# %%
def odd_even_count(numbers): 
    even_count = 0 
    odd_count = 0 

    for num in numbers: 
        if num%2 == 0: 
            even_count += 1 

        else: 
            odd_count += 1 

    return even_count, odd_count

# %%
def reversed_list(lst): 
    reversed_list = [] 
    for i in range(len(lst) -1, -1, -1): 
        reversed_list.append(lst[i]) 
    return reversed_list

# %%
# sum of the total numbers 

def sum(numbers): 
    total = 0 
    for num in numbers: 
        total += num 

    return total

# %%
def sum(numbers): 
    total = 0 
    for num in numbers: 
        total+= num 

    return total

# %%
def sum(numbers): 
    total = 0 
    for num in numbers: 
        total += num 
    return total

# %%
def sum(numbers): 
    total = 0 
    for num in numbers: 
        total += num 
    return total

# %%
def sum(numbers): 
    total = 0 
    for num in numbers: 
        total += num 
    return total

# %%
def sum(numbers): 
    total = 0 
    for num in numbers: 
        total += num 
    print(total)

# %%
def sum(numbers): 
    total = 0 

    for num in numbers: 
        total += num 

    return total

# %%
# largest numbers  

def largest_numbers(numbers): 
    largest = numbers[0] 

    for num in numbers: 
        if num > largest: 
            largest = num 
        
    return largest

# %%
def largest_numbers(numbers): 
    largest = numbers[0] 

    for num in numbers: 
        if num > largest: 
            largest = num 

    return largest

# %%
# the largest numbers 

def largest_numbers(numbers): 
    largest = numbers[0]  

    for num in numbers: 
        if num > largest: 
            largest = num 

    return largest

# %%
def largest_numbers(numbers): 
    largest = numbers[0] 

    for num in numbers: 
        if num > largest: 
            largest = num 

    return largest

# %%
def largest_numbers(numbers): 
    largest = numbers[0] 

    for num in numbers: 
        if num > largest: 
            largest = num  

    return largest

# %%
def largest(numbers): 
    largest = numbers[0] 

    for num in numbers: 
        if num > largest: 
            largest = num 

    return largest

# %%
# Finding the largest number as: 

def find_largest(numbers): 
    largest =  numbers[0] 

    for num in numbers: 
        if num > largest: 
            largest = num 

    return largest

# %%
# removing of the duplicates 

def remove_duplicates(numbers): 
    seen = set() 
    unique_list = [] 

    for num in numbers: 
        if num not in seen: 
            unique_list.append(num) 
            seen.add(num) 

    return unique_list

# %%
def remove_duplicates(numbers): 
    seen = set() 
    unique_list = [] 

    for num in numbers: 
        if num not in seen: 
            unique_list.append(num) 
            seen.add(num) 

    return unique_list

# %%
def remove_duplicates(numbers): 
    seen = set() 
    uniue_list = [] 

    for num in numbers: 
        if num not in seen: 
            unique_list.append(num) 
            seen.add(num) 

    return unique_list

# %%
def remove_duplicates(numbers): 
    seen = set() 
    unique_list = [] 

    for num in numbers: 
        if num not in seen: 
            unique_list.append(num) 
            seen.add(num) 

    return unique_list

# %%
def remove_duplicates(numbers): 
    seen = set() 
    unique_list = [] 

    for num in numbers: 
        if num not in seen: 
            unique_list.append(num) 
            seen.add(list) 

    return unique_list

# %%
# removing the duplllicates 

def remove_duplicates(numbers): 
    seen = set() 
    unique_list = [] 

    for num in numbers: 
        if num not in seen: 
            unique_list.append(num) 
            seen.add(list) 

    return unique_list

# %%
# Removing the duplicates works as: 

def remove_duplicates(numbers): 
    seen = set() 
    unique_list = [] 

    for num in numbers: 
        if num not in seen: 
            unique_list.append(num) 
            seen.add(num) 

    return unique_list

# %%
# Checking of the unique numbers 

def unique_list(numbers): 
    return len(numbers) == len(set(numbers)) \

# %%
def unique_list(numbers): 
    return len(numbers) == len(set(numbers))

# %%
def unique_list(numbers): 
    return len(numbers) == len(set(numbers))

# %%
def check_unique(numbers): 
    return len(numbers) == len(set(numbers))

# %%
def unique_list(numbers): 
    return len(numbers) == len(set(numbers))

# %%
# Checking the unique list 
def check_unique(numbers): 
    return len(numbers) == len(set(numbers))

# %%
def check_unique(numbers): 
    return len(numbers) == len(list(numbers))

# %%
def check_unique(numbers): 
    return len(numbers) == len(list(numbers))

# %%
# reversed list checking 
def reversed_list(lst): 
    reversed_list = [] 
    for i in range(lst, -1,-1,-1): 
        reversed_list.append(lst) 
    return reversed_list

# %%
# Printing the reversed list  

def reversed_list(lst): 
    reversed_list = [] 

    for i in range(lst, -1, -1, -1): 
        reversed_list.append(lst) 
    return reversed_list

# %%
def reversed_list(lst): 
    reversed_list = [] 

    for i in range(lst, -1, -1, -1): 
        reversed_list.append(lst) 
    return reversed_list

# %%
def reversed_list(lst): 
    reversed_list  = [] 

    for i in range(lst, -1, -1, -1): 
        reversed_list.append(lst) 
    return reversed_list

# %%
def reversed_numbers(lst): 
    reversed_list = [] 

    for i in range(lst, -1, -1, -1): 
        reversed_list.append(lst) 
    return reversed_list

# %%
def reversed_list(lst): 
    reversed_list = [] 

    for i in range(lst, -1, -1, -1): 
        reversed_list.append(lst) 
    return reversed_list

# %%
def remove_numbers(lst): 
    reversed_list = [] 

    for i in range(lst, -1, -1, -1): 
        reversed_list.append(lst) 
    return reversed_list

# %%
def reversed_nubers(lst): 
    reversed_list = [] 

    for i in range(lst, -1, -1, -1): 
        reversed_list.append(lst) 
    return reversed_list

# %%
def reversed_list(lst): 
    reversed_list = [] 

    for i in range(lst, -1, -1, -1): 
        reversed_list.append(lst) 

    return reversed_list

# %%
def reversed_list(lst): 
    reversed_list = [] 

    for i in range(lst, -1, -1, -1): 
        reversed_list.append(lst) 
    return reversed_list

# %%
# odd even count 

def check_odd_even(numbers): 
    even_count = 0 
    odd_count = 0 

    for num in numbers: 
        if num % 2 == 0: 
            even_count += 1 

        else: 
            odd_count += 1 

    return even_count, odd_count

# %%
def check_odd_even(numbers): 
    even_count = 0 
    odd_count = 0  

    for num in numbers: 
        if num % 2 == 0: 
            even_count += 1 
        else: 
            odd_count += 1 

    return even_count, odd_count

# %%
# check odd and even in the whole list as: 

def check_odd_even(numbers): 
    even_count = 0 
    odd_count = 0 

    for num in numbers: 
        if num%2 == 0: 
            even_count += 1 

        else: 
            odd_count += 1 

    return even_count, odd_count

# %%
def check_odd_even(numbers): 
    even_count = 0 
    odd_count = 0 

    for num in numbers: 
        if num%2 == 0: 
            even_count += 1 

        else: 
            odd_count += 1 

    return even_count, odd_count

# %%
def check_odd_even(numbers): 
    even_count = 0 
    odd_count = 0 

    for num in numbers: 
        if num%2 == 0: 
            even_count += 1 

        else: 
            odd_count += 1 

    return even_count, odd_count

# %%
def check_odd_even(numbers): 
    even_count = 0 
    odd_count = 0 

    for num in numbers: 
        if num%2 == 0: 
            even_count += 1 

        else: 
            odd_count += 1 

    return even_count, odd_count

# %%
# Checking the odd or even of the numbers as: 
def check_odd_even(numbers): 
    even_count = 0 
    odd_count = 0 

    for num in numbers: 
        if num%2 == 0: 
            even_count += 1
        else: 
            odd_count += 1 

    return even_count, odd_count

# %%
def check_odd_even(numbers): 
    even_count = 0 
    odd_count = 0 

    for num in numbers: 
        if num%2 == 0: 
            even_count += 1 

        else: 
            odd_count += 1 

    return even_count, odd_count

# %%
# Subset question is as: 

def is_subset(list1, list2): 
    for i in range(len(list2)): 
        found  =False 
        for j in range(len(list2)): 
            if list1[1] == list2[j]: 
                found + True 
                break 
        if not found: 
            return False 
    
    return True

# %%
def is_subset(list1, list2): 
    for i in range(len(list1)): 
        found = False 
        for j in range(len(list2)): 
            if list1[i] == list2[j]: 
                found = True 
                break 

        if not found: 
            return False 
        
    return True

# %%
def is_subset(list1, list2): 
    for i in range(len(list1)):
        found = False 
        for j in range(len(list2)): 
            if list1[i] == list2[j]: 
                found = True 
                break 
        if not found: 
            return False 
        
    return True

# %%
def is_subset(list1, list2): 
    for i in range(len(list1)): 
        found = False 
        for j in range(len(list2)): 
          if list1[i] == list2[j]:
             found = True 
             break 
        if not found: 
           return False
        
    return True

# %%
def is_subset(list1, list2): 
    for i in range(len(list1)): 
        found = False 
        for j in range(len(list2)): 
            if list1[i] == list2[j]: 
                found =  True 
                break 

        if not found: 
            return False 

    return True

# %%
def is_subset(list1, list2): 
    for i in range(len(list1)): 
        found = False 

        for j in range(len(list2)): 
            if list[i] == list2[j]: 
                found = True 
                break 

        if not found: 
            return False 
        
    return True

# %%
def is_subset(list1, list2): 
    for i in range(len(list1)): 
        found = False 

        for j in range(len(list2)): 
            if list1[i]== list2[j]: 
                found = False 
                break 

    return True

# %%
def is_subset(list1, list2): 
    for i in range(len(list1)): 
        found = False 

        for j in range(len(list2)): 
            if list1[i] == list2[j]: 
                found = False 
                break 

    return True

# %%
def is_subset(list1, list2): 
    for i in range(len(list1)): 
        found = False 

        for j in range(len(list2)): 
            if list1[i] == list2[j]: 
                found =  True 
                break 

    return True
