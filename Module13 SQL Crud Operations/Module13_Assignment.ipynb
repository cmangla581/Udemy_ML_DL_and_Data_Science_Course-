# %% [markdown]
# #  SQLite Assignment

# %% [markdown]
# # Assignment 1

# %% [markdown]
# Q1. Write a Python function to create a new SQLite3 database named `test.db`.

# %%
# The code for the question is as: 
import sqlite3  

def create_database(): 
    conn = sqlite3.connect('test.db') 
    conn.close() 
    print("Database created and connected successfully") 

create_database()
# Out:
# Database created and connected successfully

# %% [markdown]
# Q@. Write a Python function to create a table named `employees` with columns `id` (integer), `name` (text), `age` (integer), and `department` (text) in the `test.db` database.

# %%
# The code forthe question is  as: 
def create_table(): 
    conn = sqlite3.connect("test.db")  
    cursor = conn.cursor() 
    cursor.execute('''
    CREATE TABLE if not EXISTS employees(
                   id INTEGER PRIMARY KEY,
                   name text not null,
                   age INTEGER, 
                   department TEXT
                   )          

          ''') 
    conn.commit() 
    conn.close() 
    print("The table is created successfully") 

create_table()
# Out:
# The table is created successfully

# %% [markdown]
# # Assignment 2

# %% [markdown]
# Q1.  Write a Python function to insert a new employee into the `employees` table.

# %%
# The code for the above question is as: 
def insert_employees(id, name, age, department): 
    conn = sqlite3.connect('test.db') 
    cursor = conn.cursor() 
    cursor.execute('''
      INSERT INTO EMPLOYEES(id, name, age, department) 
       VALUES(?, ?, ? , ?)
    ''',  (id, name, age, department)) 
    
    conn.commit() 
    conn.close() 
    print("Employees inserted successfully")  


insert_employees(1, 'Alice', 30,  'HR')
# Out:
# Employees inserted successfully

# %% [markdown]
# Q2. Insert at least 5 different employees into the `employees` table.

# %%
insert_employees(2, 'Bob', 25, 'Enginneering') 
insert_employees(3, 'Charlie', 28, 'Sales') 
insert_employees(4, 'David', 35, 'Marketing') 
insert_employees(5, 'Eve', 22, 'Enginneering')
# Out:
# Employees inserted successfully
# Employees inserted successfully
# Employees inserted successfully
# Employees inserted successfully

# %% [markdown]
# # Assignment 3

# %% [markdown]
# Q1. Write a Python function to fetch and display all records from the `employees` table.

# %%
# The code of the  question is as: 

def fetch_employees(): 
    conn = sqlite3.connect('test.db') 
    cursor = conn.cursor() 
    cursor.execute('SELECT * from employees') 
    records = cursor.fetchall() 
    conn.close() 
    for record in records: 
        print(record) 

fetch_employees()
# Out:
# (1, 'Alice', 30, 'HR')
# (2, 'Bob', 25, 'Enginneering')
# (3, 'Charlie', 28, 'Sales')
# (4, 'David', 35, 'Marketing')
# (5, 'Eve', 22, 'Enginneering')

# %% [markdown]
# Q2. Write a Python function to fetch and display all employees from a specific department.

# %%
# The code of the function is as: 
def fetch_employees_by_department(department): 
    conn = sqlite3.connect('test.db') 
    cursor = conn.cursor() 
    cursor.execute('SELECT * from employees WHERE department = ?', (department,)) 
    records = cursor.fetchall() 
    conn.close() 
    for record in records: 
        print(record) 

fetch_employees_by_department('HR')
# Out:
# (1, 'Alice', 30, 'HR')

# %% [markdown]
# # Assignment 4

# %% [markdown]
# Q1. Write a Python function to update the department of an employee based on their `id`.

# %%
# The code for the aboe question is as: 

def update_employees_department(employee_id, new_department):
    conn = sqlite3.connect('test.db')
    cursor = conn.cursor()
    cursor.execute('''
        UPDATE employees
        SET department = ?
        WHERE id = ?
    ''', (new_department, employee_id))
    conn.commit()
    conn.close()
    print("Employee department updated successfully.") 

update_employees_department(1, 'Finance')
# Out:
# Employee department updated successfully.

# %% [markdown]
# Q2.  Update the department of at least 2 employees and display the updated records.

# %%
update_employees_department(2, 'Research') 
update_employees_department(3, 'Customer Support') 

fetch_employees()
# Out:
# Employee department updated successfully.
# Employee department updated successfully.
# (1, 'Alice', 30, 'Finance')
# (2, 'Bob', 25, 'Research')
# (3, 'Charlie', 28, 'Customer Support')
# (4, 'David', 35, 'Marketing')
# (5, 'Eve', 22, 'Enginneering')

# %% [markdown]
# # Assignmnet 5

# %% [markdown]
# Q1. Write a Python function to delete an employee from the `employees` table based on their `id`.

# %%
def delete_employees(employee_id): 
    conn = sqlite3.connect('test.db') 
    cursor =conn.cursor() 
    cursor.execute(''' 
           DELETE from employees 
                   WHERE id = ?          
                   ''', (employee_id,)) 
    
    conn.commit() 
    conn.close() 
    print("Employees deleted successfully") 

delete_employees(5)
# Out:
# Employees deleted successfully

# %% [markdown]
# Q2. Delete at least 1 employee and display the remaining records.

# %%
delete_employees(5) 

fetch_employees()
# Out:
# Employees deleted successfully
# (1, 'Alice', 30, 'Finance')
# (2, 'Bob', 25, 'Research')
# (3, 'Charlie', 28, 'Customer Support')
# (4, 'David', 35, 'Marketing')

# %% [markdown]
# #  Assignment 6

# %% [markdown]
# Q1. Write a Python function to fetch and display employees older than a certain age.

# %%
def fetch_employees_older_than(age): 
    conn = sqlite3.connect('test.db') 
    cursor = conn.cursor() 
    cursor.execute('SELECT * from employees where age > ?', (age,)) 
    records = cursor.fetchall() 
    conn.close() 

    for record in records: 
        print(record) 

fetch_employees_older_than(25)
# Out:
# (1, 'Alice', 30, 'Finance')
# (3, 'Charlie', 28, 'Customer Support')
# (4, 'David', 35, 'Marketing')

# %% [markdown]
# Q2. Write a Python function to fetch and display employees whose names start with a specific letter.

# %%
def fetch_employees_name_starts_with(letter):
    conn = sqlite3.connect('test.db')
    cursor = conn.cursor()
    cursor.execute('SELECT * FROM employees WHERE name LIKE ?', (letter + '%',))
    records = cursor.fetchall()
    conn.close()
    for record in records:
        print(record)

# Test the function
fetch_employees_name_starts_with('A')
# Out:
# (1, 'Alice', 30, 'Finance')

# %% [markdown]
# # Assignment 7

# %% [markdown]
# Q1. Write a Python function to insert multiple employees into the `employees` table in a single transaction. Ensure that if any insertion fails, none of the insertions are committed.

# %%
def insert_multiple_employees(employees): 
    conn = sqlite3.connect('test.db') 
    cursor = conn.cursor() 

    try: 
        cursor.executemany('''
        INSERT into employees(id, name, age, department)  
        VALUES(?, ?, ?, ?)    
      ''', (employees,)) 
        
        conn.commit()
        print("All employees inserted successfully.")
    except Exception as e:
        conn.rollback()
        print("Error occurred, transaction rolled back.")
        print(e)
    finally:
        conn.close()

employees = [
    (6, 'Frank', 40, 'Finance'),
    (7, 'Grace', 29, 'Engineering'),
    (8, 'Hannah', 35, 'Marketing'),
    (9, 'Ivan', 38, 'Sales'),
    (6, 'Jack', 45, 'HR')  # Duplicate ID to cause an error
]
insert_multiple_employees(employees)
# Out:
# Error occurred, transaction rolled back.
# Incorrect number of bindings supplied. The current statement uses 4, and there are 5 supplied.

# %% [markdown]
# Q2.  Write a Python function to update the age of multiple employees in a single transaction. Ensure that if any update fails, none of the updates are committed.

# %%
def update_multiple_employees_ages(updates):
    conn = sqlite3.connect('test.db')
    cursor = conn.cursor()
    try:
        cursor.executemany('''
            UPDATE employees
            SET age = ?
            WHERE id = ?
        ''', updates)
        conn.commit()
        print("All employee ages updated successfully.")
    except Exception as e:
        conn.rollback()
        print("Error occurred, transaction rolled back.")
        print(e)
    finally:
        conn.close() 

updates = [
    (32, 1),
    (26, 2),
    (33, 3),
    (41, 4),  
    (23, 5)
]
update_multiple_employees_ages(updates)
# Out:
# All employee ages updated successfully.

# %% [markdown]
# # Assignmnet 8

# %% [markdown]
# Q1. Create a new table named `departments` with columns `id` (integer) and `name` (text).

# %%
def create_departments_table():
    conn = sqlite3.connect('test.db')
    cursor = conn.cursor()
    cursor.execute('''
        CREATE TABLE IF NOT EXISTS departments (
            id INTEGER PRIMARY KEY,
            name TEXT NOT NULL
        )
    ''')
    conn.commit()
    conn.close()
    print("Table 'departments' created successfully.") 

create_departments_table()
# Out:
# Table 'departments' created successfully.

# %% [markdown]
# Q2. Modify the `employees` table to include a foreign key referencing the `id` column in the `departments` table.

# %%
def add_department_foreign_key():
    conn = sqlite3.connect('test.db')
    cursor = conn.cursor()
    cursor.executescript('''
        PRAGMA foreign_keys=off;
        BEGIN TRANSACTION;
        ALTER TABLE employees RENAME TO old_employees;
        CREATE TABLE employees (
            id INTEGER PRIMARY KEY,
            name TEXT NOT NULL,
            age INTEGER,
            department TEXT,
            department_id INTEGER,
            FOREIGN KEY(department_id) REFERENCES departments(id)
        );
        INSERT INTO employees (id, name, age, department)
        SELECT id, name, age, department FROM old_employees;
        DROP TABLE old_employees;
        COMMIT;
        PRAGMA foreign_keys=on;
    ''')
    conn.commit()
    conn.close()
    print("Table 'employees' modified successfully.") 

add_department_foreign_key()
# Out:
# Table 'employees' modified successfully.

# %% [markdown]
# Q3.  Write a Python function to insert data into both the `departments` and `employees` tables, ensuring referential integrity.

# %%
def insert_department_and_employee(department_id, department_name, employee_id, name, age, department):
    conn = sqlite3.connect('test.db')
    cursor = conn.cursor()
    try:
        cursor.execute('''
            INSERT INTO departments (id, name)
            VALUES (?, ?)
        ''', (department_id, department_name))
        cursor.execute('''
            INSERT INTO employees (id, name, age, department, department_id)
            VALUES (?, ?, ?, ?, ?)
        ''', (employee_id, name, age, department, department_id))
        conn.commit()
        print("Department and employee inserted successfully.")
    except Exception as e:
        conn.rollback()
        print("Error occurred, transaction rolled back.")
        print(e)
    finally:
        conn.close()

# Test the function
insert_department_and_employee(1, 'Finance', 10, 'Zara', 28, 'Finance')
# Out:
# Department and employee inserted successfully.

# %% [markdown]
# # Assignment 9

# %% [markdown]
# Q1. Create an index on the `name` column of the `employees` table.

# %%
import sqlite3

def create_index_on_name(): 
    conn = sqlite3.connect('test.db')   # fixed name
    cursor = conn.cursor()
    
    cursor.execute('CREATE INDEX IF NOT EXISTS idx_name ON employees(name)')
    
    conn.commit()
    conn.close()
    
    print("Index on 'name' column created successfully.") 

create_index_on_name()
# Out:
# Index on 'name' column created successfully.

# %% [markdown]
# Q2. Write a Python function to fetch and display all employees whose names start with a specific letter. Compare the performance with and without the index.

# %%
import time 
def fetch_employees_name_starts_with_performance(letter):
    conn = sqlite3.connect('test.db')
    cursor = conn.cursor()
    start_time = time.time()
    cursor.execute('SELECT * FROM employees WHERE name LIKE ?', (letter + '%',))
    records = cursor.fetchall()
    end_time = time.time()
    conn.close()
    print("Time taken: {} seconds".format(end_time - start_time))
    for record in records:
        print(record) 

fetch_employees_name_starts_with_performance('A')
# Out:
# Time taken: 0.001386404037475586 seconds
# (1, 'Alice', 32, 'Finance', None)

# %% [markdown]
# # Assignmnet 10

# %% [markdown]
# Q1. Write a Python function to back up the `test.db` database to a file named `backup.db`.

# %%
import shutil 

def backup_database(): 
    shutil.copy('test.db', 'backup.db') 
    print("Database backed up successfully") 

backup_database()
# Out:
# Database backed up successfully

# %% [markdown]
# Q2. Write a Python function to restore the `test.db` database from the `backup.db` file.

# %%
def restore_database(): 
    shutil.copy('backup.db', 'test.db') 
    print("Database added succesfully") 

restore_database()
# Out:
# Database added succesfully
